# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os

dataPath = "aqmaps/results/normal-data/data.csv"

data = pd.read_csv(dataPath)

display(data.head(2))
data["returnsClose"] = data["returnsClose"].astype(pd.Categorical(data["returnsClose"]),clone=False)
data["failed"] = data["failed"].astype(pd.Categorical(data["failed"]),clone=False)

data["pathfindingHeuristic"] = data["pathfindingHeuristic"].astype(pd.Categorical(data["pathfindingHeuristic"]),clone=False)
data["plannerType"] = data["plannerType"].astype(pd.Categorical(data["plannerType"]),clone=False)
data["distanceMatrixType"] = data["distanceMatrixType"].astype(pd.Categorical(data["distanceMatrixType"]),clone=False)
# Out:
#    day  month  year  moves  sensorsReached  returnsClose  time(ms)  failed  \
# 1    1   2021   105     33            True    213.088608     False     NaN
# 1    1   2021   115     33            True     67.092432     False     NaN
#
#      failedCause pathfindingHeuristic         plannerType  distanceMatrixType  \
# 1  STRAIGHT_LINE               GREEDY           EUCLIDIAN                 1.5
# 1  STRAIGHT_LINE               GREEDY  GREATEST_AVOIDANCE                 1.5
#
#    AstarRelaxationFactor  hashingGridWidth
# 1               0.000004           0.00003
# 1               0.000004           0.00003

# %%
fig,ax = plt.subplots(1)
fig.set_size_inches(30,10)
sns.scatterplot(data=data[data.plannerType=="NEAREST_INSERTION"],x=data.index,y=data.moves)
# Out:
# day                         6.519836
# month                    2020.499316
# year                       96.737688
# moves                      33.000000
# sensorsReached              1.000000
# returnsClose               34.195337
# time(ms)                    0.000000
# failed                           NaN
# distanceMatrixType          1.500000
# AstarRelaxationFactor       0.000004
# hashingGridWidth            0.000030
# dtype: float64
